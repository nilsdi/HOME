# %%
import requests
from pathlib import Path
import json
import os
import time
from requests.auth import HTTPBasicAuth

# %% [markdown]
# ##### auth string

# %%
# Get the current working directory
current_dir = Path(os.getcwd()).resolve()
#print(current_dir)

# Construct the path to the JSON file
json_file_path = os.path.join(current_dir, "geonorge_login.json")

# Open the JSON file
with open(json_file_path, "r") as file:
    # Load the JSON data
    login = json.load(file)


auth_basic = HTTPBasicAuth(login["Username"], login["Password"])
print(auth_basic)

# %% [markdown]
# ### payload

# %%
export_payload = {
"copyEmail": "nils.dittrich@ntnu.no",
"comment": "testing swagger API",
"cutNationalBorder": True,
"format": 4,
"resolution": 0.3,
"outputWkid": 	25833,
"fillColor": 0,
"fillImage": False,
"projects": [
"Trondheim 2019"
],
"compressionMethod": 5,
"compressionValue": 25,
"imagemosaic": 3,
"mapsheetSize": 2000,
"exportFilename": "testitest1.zip",
}

# %% [markdown]
# ### request

# %%
# API endpoints
export_url = "https://backend-api.klienter-prod-k8s2.norgeibilder.no/export/start"

export_response = requests.post(export_url, auth = auth_basic, json=export_payload)

print(export_response.text)
export_response.status_code
# Out:
# {"exportId":"6380024"}
# 200

# %%
exportID = export_response.json()["exportId"]
print(exportID)
print(type(exportID))
int(exportID)
# Out:
# 6380024
# <class 'str'>
# 6380024

# %% [markdown]
# ### status

# %%
status_url = f"https://backend-api.klienter-prod-k8s2.norgeibilder.no/export/{'6380024'}"
status_response = requests.get(status_url, auth = auth_basic)
print(status_response.json())
# Out:
# {'status': 'finished', 'errorMessage': None, 'urls': ['https://s3.eu-west-1.amazonaws.com/leveranser.norgeibilder.no/export/6380024/testitest1_1.zip?AWSAccessKeyId=AKIAWCT4YTQVUHQCLBZE&Expires=1732447953&Signature=NEevwvponruXTNx8y6reUgaV2u4%3D', 'https://s3.eu-west-1.amazonaws.com/leveranser.norgeibilder.no/export/6380024/testitest1_metadata.zip?AWSAccessKeyId=AKIAWCT4YTQVUHQCLBZE&Expires=1732447953&Signature=cgf31%2BXdO8F9yD4PvzLz02MNP54%3D'], 'priority': 'ikke prioritert', 'dateStarted': '2024-09-25T10:18:31', 'dateFinished': '2024-09-25T11:32:33', 'estimateTimeMinutes': 528, 'estimateSizeMB': 27671}

# %% [markdown]
# export of the original files

# %%
projectID = 4251
original_export_url = f"https://backend-api.klienter-prod-k8s2.norgeibilder.no/export/originalExport/{projectID}"
original_export_payload = {
    "copyEmail": "nils.dittrich@ntnu.no",
    "comment": "testing swagger API",
    "sendEmail": False
}

# %%
original_export_response = requests.post(original_export_url, auth = auth_basic, json= original_export_payload)

print(export_response.text)
export_response.status_code
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 original_export_response = requests.post(original_export_url, auth = auth_basic, json= original_export_payload)
# ----> 3 print(export_response.text)
#       4 export_response.status_code
#
# NameError: name 'export_response' is not defined

# %%
print(original_export_response.text)
original_export_response.status_code
# Out:
# {"success":true,"files":[{"name":"32-1-510-215-41o.sos","url":"https://s3-oslo.purity.no/nibarkiv/4251/32-1-510-215-41o.sos?AWSAccessKeyId=0090e88b33b296db001f&Expires=1735464127&Signature=Hmoj3Mw8q9f0Z7du%2BzOQThJTCng%3D","bytes":377},{"name":"32-1-508-215-47o.sos","url":"https://s3-oslo.purity.no/nibarkiv/4251/32-1-508-215-47o.sos?AWSAccessKeyId=0090e88b33b296db001f&Expires=1735464127&Signature=FWsrHcJQ52%2F4M8548hBYX3li8X8%3D","bytes":377},{"name":"32-1-512-214-37o.sos","url":"https://s3-oslo.purity.no/nibarkiv/4251/32-1-512-214-37o.sos?AWSAccessKeyId=0090e88b33b296db001f&Expires=1735464127&Signature=txndCjDRVUW3mjWDZj2N6yejZKo%3D","bytes":377},{"name":"32-1-511-216-30o.sos","url":"https://s3-oslo.purity.no/nibarkiv/4251/32-1-511-216-30o.sos?AWSAccessKeyId=0090e88b33b296db001f&Expires=1735464127&Signature=ZkCyWurisEZgX7g2sPkiuNghIwM%3D","bytes":377},{"name":"32-1-512-215-45o.tif","url":"https://s3-oslo.purity.no/nibarkiv/4251/32-1-512-215-45o.tif?AWSAccessKeyId=0090e88b33b296db001
# ...

# %%
type(original_export_response.text)
# Out:
# str

# %%
# make a json out of a str that is json formatted:
import json
response_dict = json.loads(original_export_response.text)
print(response_dict)
len(response_dict["files"])
response_dict["files"]
# Out:
# {'success': True, 'files': [{'name': '32-1-510-215-41o.sos', 'url': 'https://s3-oslo.purity.no/nibarkiv/4251/32-1-510-215-41o.sos?AWSAccessKeyId=0090e88b33b296db001f&Expires=1735464127&Signature=Hmoj3Mw8q9f0Z7du%2BzOQThJTCng%3D', 'bytes': 377}, {'name': '32-1-508-215-47o.sos', 'url': 'https://s3-oslo.purity.no/nibarkiv/4251/32-1-508-215-47o.sos?AWSAccessKeyId=0090e88b33b296db001f&Expires=1735464127&Signature=FWsrHcJQ52%2F4M8548hBYX3li8X8%3D', 'bytes': 377}, {'name': '32-1-512-214-37o.sos', 'url': 'https://s3-oslo.purity.no/nibarkiv/4251/32-1-512-214-37o.sos?AWSAccessKeyId=0090e88b33b296db001f&Expires=1735464127&Signature=txndCjDRVUW3mjWDZj2N6yejZKo%3D', 'bytes': 377}, {'name': '32-1-511-216-30o.sos', 'url': 'https://s3-oslo.purity.no/nibarkiv/4251/32-1-511-216-30o.sos?AWSAccessKeyId=0090e88b33b296db001f&Expires=1735464127&Signature=ZkCyWurisEZgX7g2sPkiuNghIwM%3D', 'bytes': 377}, {'name': '32-1-512-215-45o.tif', 'url': 'https://s3-oslo.purity.no/nibarkiv/4251/32-1-512-215-45o.tif?AWSA
# ...

# %%
import os
import requests
from tqdm import tqdm

root_dir = Path(os.getcwd()).resolve().parents[3]
print(root_dir)
def download_original_NIB(download_urls:list[dict[str]], project_name:str, data_path:str = None):
    if data_path is None:
        data_path = root_dir / "data"
    
    save_dir = (data_path / "raw/orthophoto/originals"/ project_name)
    os.makedirs(save_dir, exist_ok=True)

    for details in tqdm(download_urls):
        filename = details["name"]
        save_path = save_dir / filename
        url = details["url"]
        response = requests.get(url)
        with open(save_path, "wb") as file:
            file.write(response.content)

download_original_NIB(response_dict["files"], "Trondheim 2019")
# Out:
# /scratch/mueller_andco/orthophoto/HOME
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 22
#      19         with open(save_path, "wb") as file:
#      20             file.write(response.content)
# ---> 22 download_original_NIB(response_dict["files"], "Trondheim 2019")
#
# TypeError: download_original_NIB() missing 1 required positional argument: 'data_path'
